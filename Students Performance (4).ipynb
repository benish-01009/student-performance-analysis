# %% [markdown]
# # Students Performance Analysis Using Python

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\DELL\\Downloads\\archive.zip")
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.tail()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 999995                  4.8        100.0     A
# 999996                  6.7         88.3     A
# 999997                  5.8         87.9     A
# 999998                  5.3        100.0     A
# 999999                  4.1        100.0     A

# %%
df.shape
# Out:
# (1000000, 6)

# %%
df.describe()
# Out:
#            student_id  weekly_self_study_hours  attendance_percentage  \
# count  1000000.000000           1000000.000000         1000000.000000
# mean    500000.500000                15.029127              84.711046
# std     288675.278932                 6.899431               9.424143
# min          1.000000                 0.000000              50.000000
# 25%     250000.750000                10.300000              78.300000
# 50%     500000.500000                15.000000              85.000000
# 75%     750000.250000                19.700000              91.800000
# max    1000000.000000                40.000000             100.000000
#
#        class_participation     total_score
# count       1000000.000000  1000000.000000
# mean              5.985203       84.283845
# std               1.956421       15.432969
# min               0.000000        9.400000
# 25%               4.700000       73.900000
# 50%               6.000000       87.500000
# ...

# %%
df.isnull().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
high_attendance=df[df["attendance_percentage"]>90]
print(high_attendance)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 7                8                     20.4                  100.0
# 8                9                     11.7                  100.0
# 13              14                      1.6                   92.1
# 14              15                      2.9                   90.7
# ...            ...                      ...                    ...
# 999984      999985                     13.3                   92.3
# 999985      999986                     17.9                   99.3
# 999986      999987                     16.0                   91.0
# 999989      999990                     24.7                   90.2
# 999995      999996                     18.0                   95.5
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 7                       4.0         96.1     A
# ...

# %%
import matplotlib.pyplot as plt
df["grade"].value_counts().plot(kind="bar")
plt.show()

# %%
df["attendance_percentage"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   student_id               1000000 non-null  int64
#  1   weekly_self_study_hours  1000000 non-null  float64
#  2   attendance_percentage    1000000 non-null  float64
#  3   class_participation      1000000 non-null  float64
#  4   total_score              1000000 non-null  float64
#  5   grade                    1000000 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 45.8+ MB

# %%
df["performance"]=df["total_score"].apply(lambda x:"Excellent" if x>=85 else "Average")
df["performance"]
# Out:
# 0         Excellent
# 1           Average
# 2         Excellent
# 3         Excellent
# 4         Excellent
#             ...
# 999995    Excellent
# 999996    Excellent
# 999997    Excellent
# 999998    Excellent
# 999999    Excellent
# Name: performance, Length: 1000000, dtype: object

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade performance
# 0                  3.8         97.9     A   Excellent
# 1                  2.5         83.9     B     Average
# 2                  5.3        100.0     A   Excellent
# 3                  7.0        100.0     A   Excellent
# 4                  6.9         92.0     A   Excellent

# %%
df_small = df.head(500)

df_small.to_csv(r"C:\\Users\DELL\\Music\\project_1\\student_performance_cleaned.csv", index=False)
df_small
# Out:
#      student_id  weekly_self_study_hours  attendance_percentage  \
# 0             1                     18.5                   95.6
# 1             2                     14.0                   80.0
# 2             3                     19.5                   86.3
# 3             4                     25.7                   70.2
# 4             5                     13.4                   81.9
# ..          ...                      ...                    ...
# 495         496                     18.8                   83.2
# 496         497                      7.7                   81.4
# 497         498                     13.7                   87.0
# 498         499                      8.9                   87.4
# 499         500                      5.3                   74.2
#
#      class_participation  total_score grade performance
# 0                    3.8         97.9     A   Excellent
# 1                    2.5         83.9     B     Average
# ...

# %% [markdown]
# ## Insights and Conclusions
# 1. Students with higher self-study hours generally achieved better scores.
# 2. Students with higher attendance percentage performed better academically.
# 3. Most students fall in the average performance category.
